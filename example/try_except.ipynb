# %%
a=5
b=0
c=a/b
print(c)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12376/1471799439.py in <module>
#       1 a=5
#       2 b=0
# ----> 3 c=a/b
#       4 print(c)
#
# ZeroDivisionError: division by zero

# %%
a=5
b=0
if b != 0:
	c=a/b
	print(c)
else:
	print('b <> 0')
# Out:
# b <> 0

# %%
a=5
b=0

try:
	c=a/b
	print(c)
except:
	print('error >>>')
# Out:
# error >>>

# %%
a=5
b=0

try:
	c=a/b
	print(c)
except Exception as e:
	print(e)
# Out:
# division by zero

# %%
print('hello')
# Out:
# hello

# %%
import pandas as pd

# %%
df=pd.read_csv('bigmac_index.csw')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12376/3783598587.py in <module>
# ----> 1 df=pd.read_csv('bigmac_index.csw')
#       2 df
#
# c:\Users\prasert\miniconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
try:
	df=pd.read_csv('bigmac_index.csv')
except:
	df=pd.read_excel('bigmac_index.xlsx')
df
# Out:
#           date iso_a3 currency_code                  name  local_price  \
# 0   2011-07-01    ARG           ARS             Argentina        20.00
# 1   2011-07-01    AUS           AUD             Australia         4.56
# 2   2011-07-01    BRA           BRL                Brazil         9.50
# 3   2011-07-01    GBR           GBP               Britain         2.39
# 4   2011-07-01    CAN           CAD                Canada         4.73
# ..         ...    ...           ...                   ...          ...
# 752 2021-01-01    UKR           UAH               Ukraine        62.00
# 753 2021-01-01    ARE           AED  United Arab Emirates        14.75
# 754 2021-01-01    USA           USD         United States         5.66
# 755 2021-01-01    URY           UYU               Uruguay       204.00
# 756 2021-01-01    VNM           VND               Vietnam     66000.00
#
#         dollar_ex  dollar_price  GDP_dollar  adj_price      USD      EUR  \
# ...

# %%
try:
	df=pd.read_csv('bigmac_index.csv')
except:
	try:
		df=pd.read_excel('bigmac_index.xlsx')
	except Exception as e:
		df=pd.read_excel('http;sasdf')
df
# Out:
#           date iso_a3 currency_code                  name  local_price  \
# 0   2011-07-01    ARG           ARS             Argentina        20.00
# 1   2011-07-01    AUS           AUD             Australia         4.56
# 2   2011-07-01    BRA           BRL                Brazil         9.50
# 3   2011-07-01    GBR           GBP               Britain         2.39
# 4   2011-07-01    CAN           CAD                Canada         4.73
# ..         ...    ...           ...                   ...          ...
# 752 2021-01-01    UKR           UAH               Ukraine        62.00
# 753 2021-01-01    ARE           AED  United Arab Emirates        14.75
# 754 2021-01-01    USA           USD         United States         5.66
# 755 2021-01-01    URY           UYU               Uruguay       204.00
# 756 2021-01-01    VNM           VND               Vietnam     66000.00
#
#         dollar_ex  dollar_price  GDP_dollar  adj_price      USD      EUR  \
# ...

# %%
try:
	menu=e.select_one('div.detail').text # <div class="detail">latte</div>
except:
	# menu="None"
	try:
		menu=e.select_one('div.detail_th').text # <div class="detail">latte</div>
	except:
		menu="---"
