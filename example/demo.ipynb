# %%
import pandas as pd

# %%
df=pd.read_excel('https://github.com/prasertcbs/454_eda_data/raw/main/Passport_Stats_16-02-2022_0300_GMT.xls', skiprows=5, skipfooter=7)
df
# Out:
#    Geography           Category           Brand Name  \
# 0        USA  Grocery Retailers  Walmart Supercenter
# 1        USA  Grocery Retailers               Publix
# 2        USA  Grocery Retailers               Kroger
# 3        USA  Grocery Retailers              Safeway
# 4        USA  Grocery Retailers                H-E-B
# ..       ...                ...                  ...
# 70       USA  Grocery Retailers              Stripes
# 71       USA  Grocery Retailers              Stripes
# 72       USA  Grocery Retailers          Whole Foods
# 73       USA  Grocery Retailers           Winn-Dixie
# 74       USA  Grocery Retailers               Others
#
#            Company Name (GBO)                        Data Type  2016  2017  \
# 0                 Walmart Inc  Retail Value RSP excl Sales Tax  24.2  24.3
# 1    Publix Super Markets Inc  Retail Value RSP excl Sales Tax   3.1   3.1
# 2                   Kroger Co  Retail Value RSP excl Sales Tax   4.1   4.2
# ...
