# %%
import pandas as pd

print(f'pandas version = {pd.__version__}')
pd.Timestamp.now()
# Out:
# pandas version = 1.5.2
# Timestamp('2023-01-18 10:58:37.552819')

# %%
df=pd.read_csv('https://github.com/prasertcbs/454_2566/raw/main/example/nutrients.csv', na_values=['t', "t'"])
df
# Out:
#                       Food Measure  Grams Calories  Protein   Fat  Sat.Fat  \
# 0               Cows' milk   1 qt.    976      660     32.0  40.0     36.0
# 1                Milk skim   1 qt.    984      360     36.0   NaN      NaN
# 2               Buttermilk   1 cup    246      127      9.0   5.0      4.0
# 3    Evaporated, undiluted   1 cup    252      345     16.0  20.0     18.0
# 4           Fortified milk  6 cups  1,419    1,373     89.0  42.0     23.0
# ..                     ...     ...    ...      ...      ...   ...      ...
# 330    Fruit-flavored soda  12 oz.    346      161      0.0   0.0      0.0
# 331             Ginger ale  12 oz.    346      105      0.0   0.0      0.0
# 332              Root beer  12 oz.    346      140      0.0   0.0      0.0
# 333                 Coffee   1 cup    230        3      NaN   0.0      0.0
# 334                    Tea   1 cup    230        4      0.0   NaN      0.0
#
#     Fiber  Carbs                   Category
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 335 entries, 0 to 334
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Food      335 non-null    object
#  1   Measure   335 non-null    object
#  2   Grams     335 non-null    object
#  3   Calories  334 non-null    object
#  4   Protein   296 non-null    float64
#  5   Fat       219 non-null    float64
#  6   Sat.Fat   318 non-null    float64
#  7   Fiber     309 non-null    object
#  8   Carbs     322 non-null    float64
#  9   Category  335 non-null    object
# dtypes: float64(4), object(6)
# memory usage: 26.3+ KB

# %%
df['Calories'].str.replace(',', '', regex=False).str.replace('-', '', regex=False)
# Out:
# 0       660
# 1       360
# 2       127
# 3       345
# 4      1373
#        ...
# 330     161
# 331     105
# 332     140
# 333       3
# 334       4
# Name: Calories, Length: 335, dtype: object

# %%
# df['Calories']=pd.to_numeric(df['Calories'].str.replace(r'[,-]', '', regex=True))

# %%
# df['Calories'].mean()

# %%
df.columns
# Out:
# Index(['Food', 'Measure', 'Grams', 'Calories', 'Protein', 'Fat', 'Sat.Fat',
#        'Fiber', 'Carbs', 'Category'],
#       dtype='object')

# %%
cols=['Grams', 'Calories', 'Fiber']
for c in cols:
    df[c]=pd.to_numeric(df[c].str.replace(r'[,a\-]', '', regex=True))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 335 entries, 0 to 334
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Food      335 non-null    object
#  1   Measure   335 non-null    object
#  2   Grams     335 non-null    int64
#  3   Calories  334 non-null    float64
#  4   Protein   296 non-null    float64
#  5   Fat       219 non-null    float64
#  6   Sat.Fat   318 non-null    float64
#  7   Fiber     308 non-null    float64
#  8   Carbs     322 non-null    float64
#  9   Category  335 non-null    object
# dtypes: float64(6), int64(1), object(3)
# memory usage: 26.3+ KB

# %%
df.describe()
# Out:
#              Grams     Calories     Protein         Fat     Sat.Fat  \
# count   335.000000   334.000000  296.000000  219.000000  318.000000
# mean    143.211940   191.251497    9.702703   13.063927    6.742138
# std     138.668626   187.687099   18.575895   23.262671   18.896435
# min      11.000000     0.000000   -1.000000    0.000000    0.000000
# 25%      60.000000    75.000000    1.000000    1.000000    0.000000
# 50%     108.000000   133.500000    4.000000    8.000000    0.000000
# 75%     200.000000   250.000000   13.000000   14.000000    8.000000
# max    1419.000000  1373.000000  232.000000  233.000000  234.000000
#
#             Fiber       Carbs
# count  308.000000  322.000000
# mean     2.576656   25.990994
# std     16.729786   36.189993
# min      0.000000    0.000000
# 25%      0.000000    6.000000
# 50%      0.400000   15.000000
# 75%      1.200000   32.000000
# max    235.000000  236.000000

# %%
df.groupby('Category').describe()
# Out:
#                                  Grams                                         \
#                                  count        mean         std    min     25%
# Category
# Breads, cereals, fastfood,grains  45.0  116.733333  109.076162   11.0   30.00
# Dairy products                    28.0  264.714286  330.866299   17.0   85.00
# Desserts, sweets                  29.0  102.000000   77.369245   12.0   40.00
# Drinks,Alcohol, Beverages         12.0  273.666667  129.810585   28.0  202.50
# Fats, Oils, Shortenings           14.0   49.642857   46.443692   14.0   14.00
# Fish, Seafood                     19.0   99.578947   32.736856   85.0   85.00
# Fruits A-F                        22.0  174.727273   88.438400   42.0  114.00
# Fruits G-P                        28.0  193.285714   68.774919   60.0  136.25
# Fruits R-Z                         8.0  246.625000  281.933091   88.0  100.00
# Jams, Jellies                      8.0   52.750000   68.351507   20.0   20.00
# ...

# %%
df['Protein'] < 0
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 330    False
# 331    False
# 332    False
# 333    False
# 334    False
# Name: Protein, Length: 335, dtype: bool

# %%
df[df['Protein'] < 0]
# Out:
#              Food    Measure  Grams  Calories  Protein  Fat  Sat.Fat  Fiber  \
# 141  French-fried  10 pieces     60     155.0     -1.0  7.0      3.0    0.4
#
#      Carbs        Category
# 141   20.0  Vegetables R-Z

# %%
df['Protein'].abs()
# Out:
# 0      32.0
# 1      36.0
# 2       9.0
# 3      16.0
# 4      89.0
#        ...
# 330     0.0
# 331     0.0
# 332     0.0
# 333     NaN
# 334     0.0
# Name: Protein, Length: 335, dtype: float64

# %%
df.columns
# Out:
# Index(['Food', 'Measure', 'Grams', 'Calories', 'Protein', 'Fat', 'Sat.Fat',
#        'Fiber', 'Carbs', 'Category'],
#       dtype='object')

# %%
cols=['Grams', 'Calories', 'Protein', 'Fat', 'Sat.Fat',
       'Fiber', 'Carbs']
for col in cols:
    df[col]=df[col].abs()

# %%
df.groupby('Category').describe()
# Out:
#                                  Grams                                         \
#                                  count        mean         std    min     25%
# Category
# Breads, cereals, fastfood,grains  45.0  116.733333  109.076162   11.0   30.00
# Dairy products                    28.0  264.714286  330.866299   17.0   85.00
# Desserts, sweets                  29.0  102.000000   77.369245   12.0   40.00
# Drinks,Alcohol, Beverages         12.0  273.666667  129.810585   28.0  202.50
# Fats, Oils, Shortenings           14.0   49.642857   46.443692   14.0   14.00
# Fish, Seafood                     19.0   99.578947   32.736856   85.0   85.00
# Fruits A-F                        22.0  174.727273   88.438400   42.0  114.00
# Fruits G-P                        28.0  193.285714   68.774919   60.0  136.25
# Fruits R-Z                         8.0  246.625000  281.933091   88.0  100.00
# Jams, Jellies                      8.0   52.750000   68.351507   20.0   20.00
# ...
